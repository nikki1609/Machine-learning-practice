# %%
import seaborn as sns
import pandas as pd

# %%
tip=sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tip['total_bill'])

# %%
sns.distplot(tip['total_bill'],kde=False)

# %%
sns.distplot(tip['total_bill'],kde=False,bins=40)

# %%
sns.jointplot(x=tip['total_bill'],y=tip['tip'],data=tip)

# %%
sns.jointplot(x='total_bill',y=tip['tip'],data=tip,kind='hex')

# %%
sns.jointplot(x='total_bill',y=tip['tip'],data=tip,kind='reg')

# %%
sns.jointplot(x='total_bill',y=tip['tip'],data=tip,kind='kde')

# %%
sns.pairplot(tip)

# %%
sns.pairplot(tip,hue='sex')
